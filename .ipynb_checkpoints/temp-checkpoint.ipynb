# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import rebound 
import reboundx
from reboundx import constants
from astropy import constants as const
years = 2.*np.pi
G = const.G.value
c = const.c.value
M_jup = const.M_jup.value
M_sun = const.M_sun.value
au = const.au.value
R_jup = const.R_jup.value
Q = 1.0e5 #tidal quality factor
k = 0.26 #tidal Love number

# %%
sim = rebound.Simulation()
sim.add("Sun")
#sim.add("Vesta")
sim.add("1980 LB")
sim.add("Jupiter")
# Out:
# Searching NASA Horizons for 'Sun'... Found: Sun (10).
# Searching NASA Horizons for '1980 LB'... Found: 2938 Hopi (1980 LB).
# Searching NASA Horizons for 'Jupiter'...
# /storage/home/len56/.local/lib/python3.6/site-packages/rebound/horizons.py:140: RuntimeWarning: Warning: Mass cannot be retrieved from NASA HORIZONS. Set to 0.
#   warnings.warn("Warning: Mass cannot be retrieved from NASA HORIZONS. Set to 0.", RuntimeWarning)
# Found: Jupiter Barycenter (5).

# %%
fig = rebound.OrbitPlot(sim,slices=0.5,xlim=[-5.5,5.5],ylim=[-5.5,5.5])
for orbit in sim.calculate_orbits():
    print(orbit)
ps = sim.particles
# Out:
# <rebound.Orbit instance, a=3.151267537397213 e=0.3282003351362919 inc=0.7232738216354353 Omega=1.900122502363951 omega=-1.6845823762191672 f=-0.5068433382177546>
# <rebound.Orbit instance, a=5.203435283277991 e=0.04872323462160793 inc=0.022752695218887595 Omega=1.7543473525090034 omega=-1.5097703484696658 f=4.552430698255378>

# %%
times
# Out:
# array([  0.        ,   6.34665183,  12.69330365,  19.03995548,
#         25.3866073 ,  31.73325913,  38.07991095,  44.42656278,
#         50.7732146 ,  57.11986643,  63.46651825,  69.81317008,
#         76.15982191,  82.50647373,  88.85312556,  95.19977738,
#        101.54642921, 107.89308103, 114.23973286, 120.58638468,
#        126.93303651, 133.27968833, 139.62634016, 145.97299198,
#        152.31964381, 158.66629564, 165.01294746, 171.35959929,
#        177.70625111, 184.05290294, 190.39955476, 196.74620659,
#        203.09285841, 209.43951024, 215.78616206, 222.13281389,
#        228.47946572, 234.82611754, 241.17276937, 247.51942119,
#        253.86607302, 260.21272484, 266.55937667, 272.90602849,
#        279.25268032, 285.59933214, 291.94598397, 298.2926358 ,
#        304.63928762, 310.98593945, 317.33259127, 323.6792431 ,
#        330.02589492, 336.37254675, 342.71919857, 349.0658504 ,
#        355.41250222, 361.75915405, 368.10580588, 374.4524577 ,
# ...

# %%
Nout = 1000
times = np.linspace(0,1e6*years,Nout)
sim.integrator = "ias15" 
sim.move_to_com()        
e = np.zeros(len(times))
inc = np.zeros(len(times))

for i,time in enumerate(times):
    sim.integrate(time)
    e[i] = ps[1].e 
    inc[i] = ps[1].inc
times = times/(2.*np.pi)

# %%
fig,ax = plt.subplots(2,1)
t0 = 1e3
tmax = 5e5

ax[0].plot(times/t0,e)
ax[0].set_xlim(0,tmax/t0)
#plt.xlabel('Time (kyr)')
#plt.ylabel('Eccentricity')
ax[1].plot(times/t0,np.degrees(inc))
ax[1].set_xlim(0,tmax/t0)
# Out:
# (0, 500.0)

# %%
len(e)
# Out:
# 100
